# %% [markdown]
# ### The IMDB dataset

# %% [markdown]
# **Loading the IMDB dataset**

# %%
from tensorflow.keras.datasets import imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# 1

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %% [markdown]
# **Decoding reviews back to text**

# %%
word_index = imdb.get_word_index()
reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()])
decoded_review = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step
# 1654784/1641221 [==============================] - 0s 0us/step

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# **Encoding the integer sequences via multi-hot encoding**

# %%
import numpy as np
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, j] = 1.
    return results
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %% [markdown]
# ### Building your model

# %% [markdown]
# **Model definition**

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# **Compiling the model**

# %%
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### Validating your approach

# %% [markdown]
# **Setting aside a validation set**

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %% [markdown]
# **Training your model**

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 2s 28ms/step - loss: 0.5058 - accuracy: 0.7959 - val_loss: 0.3822 - val_accuracy: 0.8684
# Epoch 2/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.2939 - accuracy: 0.9053 - val_loss: 0.2989 - val_accuracy: 0.8865
# Epoch 3/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.2194 - accuracy: 0.9272 - val_loss: 0.3122 - val_accuracy: 0.8737
# Epoch 4/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1705 - accuracy: 0.9449 - val_loss: 0.2820 - val_accuracy: 0.8886
# Epoch 5/20
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1396 - accuracy: 0.9552 - val_loss: 0.3089 - val_accuracy: 0.8796
# Epoch 6/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1131 - accuracy: 0.9646 - val_loss: 0.3003 - val_accuracy: 0.8839
# Epoch 7/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0935 - accuracy: 0.9729 - val_loss: 0.3202 - val_accuracy: 0.8790
# Epoch 8/20
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0774 - accuracy: 0.9776 - val_loss: 0.3664 - val_accuracy: 0.8688
# Epoch 9/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0606 - accuracy: 0.9850 - val_loss: 0.3648 - val_accuracy: 0.8759
# Epoch 10/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0530 - accuracy: 0.9854 - val_loss: 0.3820 - val_accuracy: 0.8790
# Epoch 11/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0418 - accuracy: 0.9905 - val_loss: 0.4128 - val_accuracy: 0.8778
# Epoch 12/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0318 - accuracy: 0.9942 - val_loss: 0.4612 - val_accuracy: 0.8767
# Epoch 13/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0258 - accuracy: 0.9949 - val_loss: 0.4727 - val_accuracy: 0.8724
# Epoch 14/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0202 - accuracy: 0.9968 - val_loss: 0.5035 - val_accuracy: 0.8706
# Epoch 15/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0151 - accuracy: 0.9983 - val_loss: 0.5430 - val_accuracy: 0.8703
# Epoch 16/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0139 - accuracy: 0.9980 - val_loss: 0.5774 - val_accuracy: 0.8668
# Epoch 17/20
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0067 - accuracy: 0.9997 - val_loss: 0.6167 - val_accuracy: 0.8703
# Epoch 18/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0103 - accuracy: 0.9977 - val_loss: 0.6582 - val_accuracy: 0.8695
# Epoch 19/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0037 - accuracy: 0.9999 - val_loss: 0.6821 - val_accuracy: 0.8671
# Epoch 20/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0066 - accuracy: 0.9989 - val_loss: 0.7240 - val_accuracy: 0.8659

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# **Plotting the training and validation loss**

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# **Plotting the training and validation accuracy**

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# **Retraining a model from scratch**

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 1s 17ms/step - loss: 0.4507 - accuracy: 0.8270
# Epoch 2/4
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2626 - accuracy: 0.9091
# Epoch 3/4
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2031 - accuracy: 0.9274
# Epoch 4/4
# 49/49 [==============================] - 1s 13ms/step - loss: 0.1693 - accuracy: 0.9405
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2898 - accuracy: 0.8846

# %%
results
# Out:
# [0.28979015350341797, 0.8845999836921692]

# %% [markdown]
# ### Using a trained model to generate predictions on new data

# %%
model.predict(x_test)
# Out:
# array([[0.21447358],
#        [0.99939   ],
#        [0.7527422 ],
#        ...,
#        [0.1438539 ],
#        [0.10350209],
#        [0.652477  ]], dtype=float32)

# %% [markdown]
# ### Further experiments

# %% [markdown]
# ### Wrapping up

# %% [markdown]
# ## Classifying newswires: A multiclass classification example

# %% [markdown]
# ### The Reuters dataset

# %% [markdown]
# **Loading the Reuters dataset**

# %%
from tensorflow.keras.datasets import reuters
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(
    num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2113536/2110848 [==============================] - 0s 0us/step
# 2121728/2110848 [==============================] - 0s 0us/step

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %% [markdown]
# **Decoding newswires back to text**

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = " ".join([reverse_word_index.get(i - 3, "?") for i in
    train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 557056/550378 [==============================] - 0s 0us/step
# 565248/550378 [==============================] - 0s 0us/step

# %%
train_labels[10]
# Out:
# 3

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# **Encoding the input data**

# %%
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %% [markdown]
# **Encoding the labels**

# %%
def to_one_hot(labels, dimension=46):
    results = np.zeros((len(labels), dimension))
    for i, label in enumerate(labels):
        results[i, label] = 1.
    return results
y_train = to_one_hot(train_labels)
y_test = to_one_hot(test_labels)

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# ### Building your model

# %% [markdown]
# **Model definition**

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(46, activation="softmax")
])

# %% [markdown]
# **Compiling the model**

# %%
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### Validating your approach

# %% [markdown]
# **Setting aside a validation set**

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %% [markdown]
# **Training the model**

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 1s 37ms/step - loss: 2.5882 - accuracy: 0.5071 - val_loss: 1.6951 - val_accuracy: 0.6460
# Epoch 2/20
# 16/16 [==============================] - 0s 28ms/step - loss: 1.3917 - accuracy: 0.7058 - val_loss: 1.2902 - val_accuracy: 0.7120
# Epoch 3/20
# 16/16 [==============================] - 1s 32ms/step - loss: 1.0295 - accuracy: 0.7789 - val_loss: 1.1259 - val_accuracy: 0.7460
# Epoch 4/20
# 16/16 [==============================] - 1s 33ms/step - loss: 0.8048 - accuracy: 0.8322 - val_loss: 1.0163 - val_accuracy: 0.7960
# Epoch 5/20
# 16/16 [==============================] - 0s 28ms/step - loss: 0.6352 - accuracy: 0.8680 - val_loss: 0.9557 - val_accuracy: 0.8050
# Epoch 6/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5020 - accuracy: 0.8959 - val_loss: 0.9139 - val_accuracy: 0.8020
# Epoch 7/20
# 16/16 [==============================] - 0s 31ms/step - loss: 0.4065 - accuracy: 0.9176 - val_loss: 0.8829 - val_accuracy: 0.8220
# Epoch 8/20
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3253 - accuracy: 0.9306 - val_loss: 0.9005 - val_accuracy: 0.8100
# Epoch 9/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2692 - accuracy: 0.9402 - val_loss: 0.8936 - val_accuracy: 0.8050
# Epoch 10/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2301 - accuracy: 0.9451 - val_loss: 0.9040 - val_accuracy: 0.8140
# Epoch 11/20
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1973 - accuracy: 0.9508 - val_loss: 0.9692 - val_accuracy: 0.8000
# Epoch 12/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1763 - accuracy: 0.9501 - val_loss: 0.9283 - val_accuracy: 0.8150
# Epoch 13/20
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1593 - accuracy: 0.9525 - val_loss: 0.9459 - val_accuracy: 0.8160
# Epoch 14/20
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1465 - accuracy: 0.9563 - val_loss: 0.9684 - val_accuracy: 0.8020
# Epoch 15/20
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1314 - accuracy: 0.9573 - val_loss: 1.0260 - val_accuracy: 0.8060
# Epoch 16/20
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1338 - accuracy: 0.9551 - val_loss: 1.0337 - val_accuracy: 0.8030
# Epoch 17/20
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1218 - accuracy: 0.9575 - val_loss: 1.0430 - val_accuracy: 0.8130
# Epoch 18/20
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1155 - accuracy: 0.9578 - val_loss: 1.0332 - val_accuracy: 0.8060
# Epoch 19/20
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1151 - accuracy: 0.9553 - val_loss: 1.0554 - val_accuracy: 0.8050
# Epoch 20/20
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1085 - accuracy: 0.9574 - val_loss: 1.0993 - val_accuracy: 0.7960

# %% [markdown]
# **Plotting the training and validation loss**

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# **Plotting the training and validation accuracy**

# %%
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# **Retraining a model from scratch**

# %%
model = keras.Sequential([
  layers.Dense(64, activation="relu"),
  layers.Dense(64, activation="relu"),
  layers.Dense(46, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.fit(x_train,
          y_train,
          epochs=9,
          batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/9
# 18/18 [==============================] - 1s 30ms/step - loss: 2.4307 - accuracy: 0.5553
# Epoch 2/9
# 18/18 [==============================] - 1s 29ms/step - loss: 1.3571 - accuracy: 0.7025
# Epoch 3/9
# 18/18 [==============================] - 1s 31ms/step - loss: 1.0094 - accuracy: 0.7779
# Epoch 4/9
# 18/18 [==============================] - 1s 29ms/step - loss: 0.7832 - accuracy: 0.8336
# Epoch 5/9
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6134 - accuracy: 0.8722
# Epoch 6/9
# 18/18 [==============================] - 0s 25ms/step - loss: 0.4940 - accuracy: 0.8951
# Epoch 7/9
# 18/18 [==============================] - 0s 26ms/step - loss: 0.3952 - accuracy: 0.9147
# Epoch 8/9
# 18/18 [==============================] - 0s 25ms/step - loss: 0.3246 - accuracy: 0.9305
# Epoch 9/9
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2686 - accuracy: 0.9397
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9764 - accuracy: 0.7881

# %%
results
# Out:
# [0.9764123558998108, 0.7880676984786987]

# %%
import copy
test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
hits_array = np.array(test_labels) == np.array(test_labels_copy)
hits_array.mean()
# Out:
# 0.18477292965271594

# %% [markdown]
# ### Generating predictions on new data

# %%
predictions = model.predict(x_test)

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# 1.0

# %%
np.argmax(predictions[0])
# Out:
# 3

# %% [markdown]
# ### A different way to handle the labels and the loss

# %%
y_train = np.array(train_labels)
y_test = np.array(test_labels)

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### The importance of having sufficiently large intermediate layers

# %% [markdown]
# **A model with an information bottleneck**

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(4, activation="relu"),
    layers.Dense(46, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 13ms/step - loss: 3.0755 - accuracy: 0.2117 - val_loss: 2.6253 - val_accuracy: 0.2320
# Epoch 2/20
# 63/63 [==============================] - 1s 11ms/step - loss: 2.2439 - accuracy: 0.2974 - val_loss: 1.9592 - val_accuracy: 0.3180
# Epoch 3/20
# 63/63 [==============================] - 1s 13ms/step - loss: 1.6212 - accuracy: 0.5609 - val_loss: 1.6006 - val_accuracy: 0.6540
# Epoch 4/20
# 63/63 [==============================] - 1s 10ms/step - loss: 1.3228 - accuracy: 0.6803 - val_loss: 1.4828 - val_accuracy: 0.6570
# Epoch 5/20
# 63/63 [==============================] - 1s 13ms/step - loss: 1.1885 - accuracy: 0.6914 - val_loss: 1.4555 - val_accuracy: 0.6590
# Epoch 6/20
# 63/63 [==============================] - 1s 13ms/step - loss: 1.1023 - accuracy: 0.7051 - val_loss: 1.4427 - val_accuracy: 0.6580
# Epoch 7/20
# 63/63 [==============================] - 1s 12ms/step - loss: 1.0323 - accuracy: 0.7197 - val_loss: 1.4748 - val_accuracy: 0.6720
# Epoch 8/20
# 63/63 [==============================] - 1s 10ms/step - loss: 0.9707 - accuracy: 0.7410 - val_loss: 1.4950 - val_accuracy: 0.6740
# Epoch 9/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.9186 - accuracy: 0.7502 - val_loss: 1.5126 - val_accuracy: 0.6780
# Epoch 10/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8749 - accuracy: 0.7537 - val_loss: 1.5513 - val_accuracy: 0.6730
# Epoch 11/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8347 - accuracy: 0.7620 - val_loss: 1.5912 - val_accuracy: 0.6770
# Epoch 12/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.8010 - accuracy: 0.7745 - val_loss: 1.6379 - val_accuracy: 0.6760
# Epoch 13/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.7691 - accuracy: 0.7858 - val_loss: 1.7017 - val_accuracy: 0.6700
# Epoch 14/20
# 63/63 [==============================] - 1s 18ms/step - loss: 0.7394 - accuracy: 0.7915 - val_loss: 1.7428 - val_accuracy: 0.6710
# Epoch 15/20
# 63/63 [==============================] - 1s 18ms/step - loss: 0.7134 - accuracy: 0.7962 - val_loss: 1.8042 - val_accuracy: 0.6670
# Epoch 16/20
# 63/63 [==============================] - 1s 15ms/step - loss: 0.6915 - accuracy: 0.8032 - val_loss: 1.7988 - val_accuracy: 0.6770
# Epoch 17/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.6726 - accuracy: 0.8071 - val_loss: 1.8644 - val_accuracy: 0.6800
# Epoch 18/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.6535 - accuracy: 0.8089 - val_loss: 1.9702 - val_accuracy: 0.6780
# Epoch 19/20
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6372 - accuracy: 0.8128 - val_loss: 1.9775 - val_accuracy: 0.6760
# Epoch 20/20
# 63/63 [==============================] - 1s 12ms/step - loss: 0.6241 - accuracy: 0.8182 - val_loss: 2.0674 - val_accuracy: 0.6710

# %% [markdown]
# ### Further experiments

# %% [markdown]
# ### Wrapping up

# %% [markdown]
# ## Predicting house prices: A regression example

# %% [markdown]
# ### The Boston Housing Price dataset

# %% [markdown]
# **Loading the Boston housing dataset**

# %%
from tensorflow.keras.datasets import boston_housing
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step
# 65536/57026 [==================================] - 0s 0us/step

# %%
train_data.shape
# Out:
# (404, 13)

# %%
test_data.shape
# Out:
# (102, 13)

# %%
train_targets
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7, 18.5, 11.3, 15.6, 15.6, 14.4, 12.1,
#        17.9, 23.1, 19.9, 15.7,  8.8, 50. , 22.5, 24.1, 27.5, 10.9, 30.8,
#        32.9, 24. , 18.5, 13.3, 22.9, 34.7, 16.6, 17.5, 22.3, 16.1, 14.9,
#        23.1, 34.9, 25. , 13.9, 13.1, 20.4, 20. , 15.2, 24.7, 22.2, 16.7,
#        12.7, 15.6, 18.4, 21. , 30.1, 15.1, 18.7,  9.6, 31.5, 24.8, 19.1,
#        22. , 14.5, 11. , 32. , 29.4, 20.3, 24.4, 14.6, 19.5, 14.1, 14.3,
#        15.6, 10.5,  6.3, 19.3, 19.3, 13.4, 36.4, 17.8, 13.5, 16.5,  8.3,
#        14.3, 16. , 13.4, 28.6, 43.5, 20.2, 22. , 23. , 20.7, 12.5, 48.5,
#        14.6, 13.4, 23.7, 50. , 21.7, 39.8, 38.7, 22.2, 34.9, 22.5, 31.1,
#        28.7, 46. , 41.7, 21. , 26.6, 15. , 24.4, 13.3, 21.2, 11.7, 21.7,
#        19.4, 50. , 22.8, 19.7, 24.7, 36.2, 14.2, 18.9, 18.3, 20.6, 24.6,
#        18.2,  8.7, 44. , 10.4, 13.2, 21.2, 37. , 30.7, 22.9, 20. , 19.3,
#        31.7, 32. , 23.1, 18.8, 10.9, 50. , 19.6,  5. , 14.4, 19.8, 13.8,
#        19.6, 23.9, 24.5, 25. , 19.9, 17.2, 24.6, 13.5, 26.6, 21.4, 11.9,
#        22.6, 19.6,  8.5, 23.7, 23.1, 22.4, 20.5, 23.6, 18.4, 35.2, 23.1,
#        27.9, 20.6, 23.7, 28. , 13.6, 27.1, 23.6, 20.6, 18.2, 21.7, 17.1,
#         8.4, 25.3, 13.8, 22.2, 18.4, 20.7, 31.6, 30.5, 20.3,  8.8, 19.2,
#        19.4, 23.1, 23. , 14.8, 48.8, 22.6, 33.4, 21.1, 13.6, 32.2, 13.1,
#        23.4, 18.9, 23.9, 11.8, 23.3, 22.8, 19.6, 16.7, 13.4, 22.2, 20.4,
#        21.8, 26.4, 14.9, 24.1, 23.8, 12.3, 29.1, 21. , 19.5, 23.3, 23.8,
#        17.8, 11.5, 21.7, 19.9, 25. , 33.4, 28.5, 21.4, 24.3, 27.5, 33.1,
#        16.2, 23.3, 48.3, 22.9, 22.8, 13.1, 12.7, 22.6, 15. , 15.3, 10.5,
#        24. , 18.5, 21.7, 19.5, 33.2, 23.2,  5. , 19.1, 12.7, 22.3, 10.2,
#        13.9, 16.3, 17. , 20.1, 29.9, 17.2, 37.3, 45.4, 17.8, 23.2, 29. ,
#        22. , 18. , 17.4, 34.6, 20.1, 25. , 15.6, 24.8, 28.2, 21.2, 21.4,
#        23.8, 31. , 26.2, 17.4, 37.9, 17.5, 20. ,  8.3, 23.9,  8.4, 13.8,
#         7.2, 11.7, 17.1, 21.6, 50. , 16.1, 20.4, 20.6, 21.4, 20.6, 36.5,
#         8.5, 24.8, 10.8, 21.9, 17.3, 18.9, 36.2, 14.9, 18.2, 33.3, 21.8,
#        19.7, 31.6, 24.8, 19.4, 22.8,  7.5, 44.8, 16.8, 18.7, 50. , 50. ,
#        19.5, 20.1, 50. , 17.2, 20.8, 19.3, 41.3, 20.4, 20.5, 13.8, 16.5,
#        23.9, 20.6, 31.5, 23.3, 16.8, 14. , 33.8, 36.1, 12.8, 18.3, 18.7,
#        19.1, 29. , 30.1, 50. , 50. , 22. , 11.9, 37.6, 50. , 22.7, 20.8,
#        23.5, 27.9, 50. , 19.3, 23.9, 22.6, 15.2, 21.7, 19.2, 43.8, 20.3,
#        33.2, 19.9, 22.5, 32.7, 22. , 17.1, 19. , 15. , 16.1, 25.1, 23.7,
#        28.7, 37.2, 22.6, 16.4, 25. , 29.8, 22.1, 17.4, 18.1, 30.3, 17.5,
#        24.7, 12.6, 26.5, 28.7, 13.3, 10.4, 24.4, 23. , 20. , 17.8,  7. ,
#        11.8, 24.4, 13.8, 19.4, 25.2, 19.4, 19.4, 29.1])

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# **Normalizing the data**

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std
test_data -= mean
test_data /= std

# %% [markdown]
# ### Building your model

# %% [markdown]
# **Model definition**

# %%
def build_model():
    model = keras.Sequential([
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(1)
    ])
    model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
    return model

# %% [markdown]
# ### Validating your approach using K-fold validation

# %% [markdown]
# **K-fold validation**

# %%
k = 4
num_val_samples = len(train_data) // k
num_epochs = 100
all_scores = []
for i in range(k):
    print(f"Processing fold #{i}")
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)
    model = build_model()
    model.fit(partial_train_data, partial_train_targets,
              epochs=num_epochs, batch_size=16, verbose=0)
    val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
    all_scores.append(val_mae)
# Out:
# Processing fold #0
# Processing fold #1
# Processing fold #2
# Processing fold #3

# %%
all_scores
# Out:
# [1.8708012104034424, 2.663888692855835, 2.5180437564849854, 2.474630832672119]

# %%
np.mean(all_scores)
# Out:
# 2.3818411231040955

# %% [markdown]
# **Saving the validation logs at each fold**

# %%
num_epochs = 500
all_mae_histories = []
for i in range(k):
    print(f"Processing fold #{i}")
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)
    model = build_model()
    history = model.fit(partial_train_data, partial_train_targets,
                        validation_data=(val_data, val_targets),
                        epochs=num_epochs, batch_size=16, verbose=0)
    mae_history = history.history["val_mae"]
    all_mae_histories.append(mae_history)
# Out:
# Processing fold #0
# Processing fold #1
# Processing fold #2
# Processing fold #3

# %% [markdown]
# **Building the history of successive mean K-fold validation scores**

# %%
average_mae_history = [
    np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)]

# %% [markdown]
# **Plotting validation scores**

# %%
plt.plot(range(1, len(average_mae_history) + 1), average_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %% [markdown]
# **Plotting validation scores, excluding the first 10 data points**

# %%
truncated_mae_history = average_mae_history[10:]
plt.plot(range(1, len(truncated_mae_history) + 1), truncated_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %% [markdown]
# **Training the final model**

# %%
model = build_model()
model.fit(train_data, train_targets,
          epochs=130, batch_size=16, verbose=0)
test_mse_score, test_mae_score = model.evaluate(test_data, test_targets)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 19.3208 - mae: 3.0750

# %%
test_mae_score
# Out:
# 3.074977159500122

# %% [markdown]
# ### Generating predictions on new data

# %%
predictions = model.predict(test_data)
predictions[0]
# Out:
# array([9.841613], dtype=float32)
